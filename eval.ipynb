# %%
# !git clone https://github.com/naholav/CodeGen.git
# %cd CodeGen
# !pip install -r requirements.txt

# %%
# %cd /content/CodeGen
# Gerekli klasör ağacını oluşturuyoruz
# !mkdir -p models/deep_instruction/checkpoints
# !mkdir -p models/diverse_instruction/checkpoints

# %%
# !cp -r "/content/drive/MyDrive/NLPlora/DeepSon/." models/deep_instruction/checkpoints/

# !cp -r "/content/drive/MyDrive/NLPlora/Diverse/." models/diverse_instruction/checkpoints/

# %%
# %cd /content/CodeGen
# !python livecodebench_eval.py --model_type deep_instruction --platform atcoder --difficulty easy

# %%
# !python livecodebench_eval.py --model_type diverse_instruction --platform atcoder --difficulty easy
